# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
X, y = make_blobs(n_samples=500, centers=3, n_features=5,random_state=0)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-0.66822957, -1.63525509,  1.07118066,  0.47702424,  0.50392214],
#        [ 1.11701463,  0.75404287, -0.76918187,  0.64685406, -0.98584765],
#        [-0.67394319, -0.96190749,  1.42781032,  0.64345075,  0.62622144],
#        ...,
#        [-0.66344222,  1.47659142, -0.72437052, -1.36442572,  0.94606982],
#        [-1.21817365,  1.29480043, -0.93793351, -0.90581516,  1.13313718],
#        [-0.77375692,  0.87832384, -0.47419754, -1.35273749,  0.47799333]])

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
df_pca = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
df_pca['label'] = y

# %%
sns.scatterplot(data=df_pca, x='PC1', y='PC2', hue='label', palette='Set1')
plt.show()
