# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotly in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (7.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from plotly) (2.25.0)
# Requirement already satisfied: packaging in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from plotly) (26.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cufflinks in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from cufflinks) (2.5.2)
# Requirement already satisfied: pandas>=0.19.2 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from cufflinks) (3.0.5)
# Requirement already satisfied: plotly>=4.1.1 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from cufflinks) (7.0.0)
# Requirement already satisfied: six>=1.9.0 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from cufflinks) (1.17.0)
# Requirement already satisfied: colorlover>=0.2.1 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from cufflinks) (84.0.0)
# Requirement already satisfied: ipython>=5.3.0 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from cufflinks) (9.16.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from cufflinks) (8.1.9)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from ipython>=5.3.0->cufflinks) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from ipython>=5.3.0->cufflinks) (3.0.53)
# Requirement already satisfied: psutil>=7 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from ipython>=5.3.0->cufflinks) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from ipython>=5.3.0->cufflinks) (2.21.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from ipython>=5.3.0->cufflinks) (5.16.1)
# Requirement already satisfied: wcwidth>=0.1.4 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.8.2)
# Requirement already satisfied: comm>=0.1.3 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.16 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.16)
# Requirement already satisfied: jupyterlab_widgets~=3.0.17 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.17)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from jedi>=0.18.2->ipython>=5.3.0->cufflinks) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from pandas>=0.19.2->cufflinks) (2026.3)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from plotly>=4.1.1->cufflinks) (2.25.0)
# Requirement already satisfied: packaging in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from plotly>=4.1.1->cufflinks) (26.3)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.2)
# Requirement already satisfied: pure-eval in C:\Users\User\AppData\Roaming\Python\Python314\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)

# %%
import seaborn as sns
import pandas as pd
import cufflinks as cf
from plotly.offline import iplot

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import plotly.express as px

fig = px.line(tips, y='tip')
fig.show()

# %%
tips.groupby('day')['tip'].mean().bar(tips)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 tips.groupby('day')['tip'].mean().bar(tips)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'bar'
