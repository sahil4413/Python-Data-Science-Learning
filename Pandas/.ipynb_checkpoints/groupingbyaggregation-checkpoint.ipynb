# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
#GROUP BY CATEGORY & CALC SUM OF SALES
cat = df.groupby('Category')
for i,v in cat:
    print(i)
    print(v)
# Out:
# A
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 2        A    S2    150        12 2023-01-03
# 4        A    S1    120         8 2023-01-05
# 6        A    S2    200        15 2023-01-07
# B
#   Category Store  Sales  Quantity       Date
# 1        B    S1    200        15 2023-01-02
# 3        B    S2    250        18 2023-01-04
# 5        B    S2    180        20 2023-01-06
# 7        B    S1    300        25 2023-01-08

# %%
cat = df.groupby('Category')['Sales'].sum()
cat
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
#Group by multiple columns
#Group by category & store
cat = df.groupby(['Category','Store'])['Sales'].sum()
cat
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %%
df['Sales'].mean()
# Out:
# np.float64(187.5)

# %%
df['Sales'].agg(['sum','min','ax','count','mean','std','median'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df['Sales'].agg(['sum','min','ax','count','mean','std','median'])
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\series.py:4808, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4805     func = dict(kwargs.items())
#    4807 op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4808 result = op.agg()
#    4809 return result
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\apply.py:1523, in SeriesApply.agg(self)
#    1522 def agg(self):
# -> 1523     result = super().agg()
#    1524     if result is None:
#    1525         obj = self.obj
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\apply.py:297, in Apply.agg(self)
#     294     return self.agg_dict_like()
#     295 elif is_list_like(func):
#     296     # we require a list, but not a 'str'
# --> 297     return self.agg_list_like()
#     299 # caller can react
#     300 return None
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\apply.py:414, in Apply.agg_list_like(self)
#     406 def agg_list_like(self) -> DataFrame | Series:
#     407     """
#     408     Compute aggregation in the case of a list-like argument.
#     409
#    (...)    412     Result of aggregation.
#     413     """
# --> 414     return self.agg_or_apply_list_like(op_name="agg")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\apply.py:843, in NDFrameApply.agg_or_apply_list_like(self, op_name)
#     840 if getattr(obj, "axis", 0) == 1:
#     841     raise NotImplementedError("axis other than 0 is not supported")
# --> 843 keys, results = self.compute_list_like(op_name, obj, kwargs)
#     844 result = self.wrap_results_list_like(keys, results)
#     845 return result
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\apply.py:457, in Apply.compute_list_like(self, op_name, selected_obj, kwargs)
#     451 colg = obj._gotitem(selected_obj.name, ndim=1, subset=selected_obj)
#     452 args = (
#     453     [self.axis, *self.args]
#     454     if include_axis(op_name, colg)
#     455     else self.args
#     456 )
# --> 457 new_res = getattr(colg, op_name)(a, *args, **kwargs)
#     458 results.append(new_res)
#     460 # make sure we find a good name
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\series.py:4808, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4805     func = dict(kwargs.items())
#    4807 op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4808 result = op.agg()
#    4809 return result
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\apply.py:1523, in SeriesApply.agg(self)
#    1522 def agg(self):
# -> 1523     result = super().agg()
#    1524     if result is None:
#    1525         obj = self.obj
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\apply.py:291, in Apply.agg(self)
#     288 func = self.func
#     290 if isinstance(func, str):
# --> 291     return self.apply_str()
#     293 if is_dict_like(func):
#     294     return self.agg_dict_like()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\apply.py:701, in Apply.apply_str(self)
#     697     if "axis" in arg_names and not isinstance(
#     698         obj, (SeriesGroupBy, DataFrameGroupBy)
#     699     ):
#     700         self.kwargs["axis"] = self.axis
# --> 701 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\apply.py:805, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     803 else:
#     804     msg = f"'{func}' is not a valid function for '{type(obj).__name__}' object"
# --> 805     raise AttributeError(msg)
#
# AttributeError: 'ax' is not a valid function for 'Series' object
