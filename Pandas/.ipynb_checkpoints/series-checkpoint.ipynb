# %%
import numpy as np 
import pandas as pd

# %%
labels = ['a','b','c']
my_list =[10,20,30]
arr = np.array([10,20,30])
d = {1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr, index =labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#DATA FRAME
data = {
    'Name' : ['John', 'Anna', 'Sahil', 'Khushi', 'Anik'],
    'Age': [15,25,24,19,18],
    'City':['New York', 'Paris', 'London', 'Spain', 'Germany'],
    'Salary':[65000,70000,56000,36000,48000]
}
df = pd.DataFrame(data)
df
# Out:
#      Name  Age      City  Salary
# 0    John   15  New York   65000
# 1    Anna   25     Paris   70000
# 2   Sahil   24    London   56000
# 3  Khushi   19     Spain   36000
# 4    Anik   18   Germany   48000

# %%
data_list = [
     ['John'	,15	,'New York',	65000],
    ['Anna' ,25,	'Paris',	70000],
    ['Sahil' ,24	,'London'	,56000],
    ['Khushi'	,19	,'Spain',	36000],
    ['Anik' ,18	,'Germany',	48000]
    ]
df2 = pd.DataFrame(data_list)
df2
columns = ["Name", "Age", "City", "Salary"]
df2 = pd.DataFrame(data_list, columns = columns)
df2
# Out:
#      Name  Age      City  Salary
# 0    John   15  New York   65000
# 1    Anna   25     Paris   70000
# 2   Sahil   24    London   56000
# 3  Khushi   19     Spain   36000
# 4    Anik   18   Germany   48000

# %%
df2['Name']
# Out:
# 0      John
# 1      Anna
# 2     Sahil
# 3    Khushi
# 4      Anik
# Name: Name, dtype: str

# %%
df2[['Name', 'Age']]
# Out:
#      Name  Age
# 0    John   15
# 1    Anna   25
# 2   Sahil   24
# 3  Khushi   19
# 4    Anik   18

# %%
df2['Designation'] = ['Doc', 'Engg.', 'Doc', 'Engg.', 'Doc']
df2
# Out:
#      Name  Age      City  Salary Designation
# 0    John   15  New York   65000         Doc
# 1    Anna   25     Paris   70000       Engg.
# 2   Sahil   24    London   56000         Doc
# 3  Khushi   19     Spain   36000       Engg.
# 4    Anik   18   Germany   48000         Doc

# %%
df2.drop('Designation', axis =1) #deletes desgnation temoporarily
# Out:
#      Name  Age      City  Salary
# 0    John   15  New York   65000
# 1    Anna   25     Paris   70000
# 2   Sahil   24    London   56000
# 3  Khushi   19     Spain   36000
# 4    Anik   18   Germany   48000

# %%
df2.drop('Designation', axis =1, inplace = True)
df2 #deleted permanently
# Out:
#      Name  Age      City  Salary
# 0    John   15  New York   65000
# 1    Anna   25     Paris   70000
# 2   Sahil   24    London   56000
# 3  Khushi   19     Spain   36000
# 4    Anik   18   Germany   48000

# %%
#SELECTING ROW
df2.loc[0]
# Out:
# Name          John
# Age             15
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  John   15  New York   65000
# 1  Anna   25     Paris   70000

# %%
#SELECTING SUBSETS OF  ROW
df2.loc[[0,1]][['City','Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
#CONDITION
df2[df2['Age'] >18]
# Out:
#      Name  Age    City  Salary
# 1    Anna   25   Paris   70000
# 2   Sahil   24  London   56000
# 3  Khushi   19   Spain   36000

# %%
df2[(df2['Age'] > 18) & (df2["City"] == 'Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   25  Paris   70000
