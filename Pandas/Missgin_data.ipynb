# %%
import numpy as np
import pandas as pd

# %%
#DICTIONARY
data = {
    'A':[1,2,np.nan,4,5],
    'B':[1, 2,3,4,5],
    'C':[1,2,3, np.nan, np.nan],
    'D':[1,np.nan, np.nan,np.nan, 5]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B    C    D
# 0  1.0  NaN  1.0  1.0
# 1  2.0  2.0  2.0  NaN
# 2  NaN  3.0  3.0  NaN
# 3  4.0  4.0  NaN  NaN
# 4  5.0  5.0  NaN  5.0

# %%
df.isna()
# Out:
#        A      B      C      D
# 0  False   True  False  False
# 1  False  False  False   True
# 2   True  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
df.isna().sum()
# Out:
# A    1
# B    1
# C    2
# D    3
# dtype: int64

# %%
df.isna().any() #TO CHECK IF EVERY ROW AS A MISSING A=DATA
# Out:
# A    True
# B    True
# C    True
# D    True
# dtype: bool

# %%
df.dropna() #removing missing data
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
df.dropna(thresh = 3)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 4  5.0  5  NaN  5.0

# %%
#fillling missing data
df.fillna(0)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  0.0
# 2  0.0  3  3.0  0.0
# 3  4.0  4  0.0  0.0
# 4  5.0  5  0.0  5.0

# %%
values = {
    'A':0,
    'B':10,
    'C':100,
    'D':10000
}
df.fillna(value = values)
# Out:
#      A  B      C        D
# 0  1.0  1    1.0      1.0
# 1  2.0  2    2.0  10000.0
# 2  0.0  3    3.0  10000.0
# 3  4.0  4  100.0  10000.0
# 4  5.0  5  100.0      5.0
